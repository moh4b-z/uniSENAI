# %% [markdown]
# # Lógica de Programação e Algoritmos
# ## Aula 3: Condicionais

# %% [markdown]
# ## Aquecimento
#
# Antes de programar, responda mentalmente:
#
# 1. Qual é a entrada do problema, isto é, o que eu preciso receber?
# 2. Qual é o processamento, isto é, quais regras e cálculos eu aplico?
# 3. Qual é a saída, isto é, o que preciso mostrar no final?

# %% [markdown]
# ## Condicional Simples: if
#
# ## Tomada de decisão
#
# Tomar decisão em um programa é escolher executar um bloco de código ou não, com base em uma condição booleana.
#
# ### Estrutura `if`
# ```python
# if condição:
#     bloco
# ```
#
# O bloco só executa quando a condição é verdadeira.

# %% [markdown]
# <div>
# <img src=attachment:77cf45ba-d760-44d0-b11c-9b828384a53b.png style="height:500px; width:auto;"/>
# </div>

# %% [markdown]
# ## Condições simples
#
# Condições simples costumam usar operadores relacionais, por exemplo:
# - `x > 10`
# - `senha == "python"`

# %%
saldo = 100
debito = float(input('Digite o valor do débito: '))

if debito < saldo:
    print('Saldo Inicial:', saldo)
    saldo = saldo - debito 
    print('Saldo Final', saldo)
print('FIM')
# Out:
# Digite o valor do débito:  10
# Saldo Inicial: 100
# Saldo Final 90.0
# FIM

# %%
senha = input('Senha:')

if senha == 'python':
    print('Acesso Liberado ')
# Out:
# Senha: python
# Acesso Liberado

# %% [markdown]
# ## Decisão humana e decisão computacional
#
# Decisão humana pode ser vaga, por exemplo "se estiver frio, leve casaco".
# Decisão computacional precisa de regra mensurável, por exemplo "se temperatura < 18".

# %%
temp = float(input('Temperatura em celsius:'))
if temp < 18:
    print('Leve Casaco')
# Out:
# Temperatura em celsius: 17
# Leve Casaco

# %% [markdown]
# ## Estrutura `if / else`
#
# Quando existem dois caminhos mutuamente exclusivos, use `else`.
#
# ```python
# if condição:
#     caminho_A
# else:
#     caminho_B
# ```
#
# A ideia é garantir que exatamente um caminho seja escolhido.

# %% [markdown]
# <div>
# <img src=attachment:7f6bc8ae-ea25-4928-add1-2c0645452fa3.png style="height:500px; width:auto;"/>
# </div>

# %%
saldo = 100
debito = float(input('Digite o valor do débito: '))

if debito < saldo:
    print('Saldo Inicial:', saldo)
    saldo = saldo - debito 
    print('Saldo Final', saldo)
else:
    diferenca = debito - saldo 
    print('Saldo é insuficiente! \nDeposite', diferenca, 'reais para continuar')
# Out:
# Digite o valor do débito:  150
# Saldo é insuficiente!
# Deposite 50.0 reais para continuar

# %%
senha = input('Senha:')

if senha == 'python':
    print('Acesso Liberado ')
else:
    print('Acesso Negado: Senha Incorreta!')
# Out:
# Senha: 25
# Acesso Negado

# %% [markdown]
# ## Casos mutuamente exclusivos e erros comuns
#
# Erros típicos:
# - condição invertida
# - esquecimento de atualizar variável antes de decidir
# - usar `==` quando deveria usar `>=` ou `<=`
#
# Uma boa prática é testar casos de borda, por exemplo 17, 18, 19.

# %%
for idade in [17, 18, 19]:
    msg = 'Maior' if idade >= 18 else 'Menor'
    print(idade, '->', msg)
# Out:
# 17 -> Menor
# 18 -> Maior
# 19 -> Maior

# %% [markdown]
# ## Estrutura `if / elif / else`
#
# Quando há mais de dois caminhos, use `elif` para encadear decisões.
#
# ```python
# if cond1:
#     ...
# elif cond2:
#     ...
# else:
#     ...
# ```
#
# A primeira condição verdadeira determina o caminho, as demais são ignoradas.
#
# <div>
# <img src=attachment:3e579a9e-845b-45c3-b39c-4ec33ca534d7.png style="height:500px; width:auto;"/>
# </div>
#
#
#
# ## Prioridade de condições
#
# A ordem importa. Coloque primeiro as regras mais específicas ou mais restritivas.
# Um bom método é escrever a tabela de decisão antes.
#
# ## Tabela de decisão
#
# Crie uma tabela simples para validar lógica:
#
# | Faixa | Condição | Saída |
# |---|---|---|
# | A | nota >= 9 | "A" |
# | B | 7 <= nota < 9 | "B" |
# | C | 5 <= nota < 7 | "C" |
# | D | nota < 5 | "D" |

# %%
nota = float(input('Nota (0 a 10):'))

if nota >= 9:
    conceito = 'A'
elif nota >= 7:
    conceito = 'B'
elif nota >= 5:
    conceito = 'C'
else:
    conceito = 'D'
print('Conceito:', conceito)
# Out:
# Nota (0 a 10): 10
# Conceito: A

# %% [markdown]
# ## Lista de exercícios
#
# 1. Leia um número e, se for negativo, imprima uma mensagem de alerta.
# 2. Crie um verificador simples de entrada. Dado um valor, se ele for múltiplo de 2, imprima 'par'.
# 3. Crie uma regra de frete grátis: se a compra for acima de um limite, informe frete grátis.
# 4. Leia a idade e informe se é 'maior de idade' ou 'menor de idade'.
# 5. Crie um programa que decide entre 'aprovado' e 'reprovado' com base em uma nota.
# 6. Compare dois números e informe qual é o maior ou se são iguais.
# 7. Implemente uma escolha de menu com 2 opções usando if/else.
# 8. Implemente a cobrança de estacionamento por faixas de horas.
# 9. Monte uma tabela de decisão para triagem (baixa, média, alta) e implemente com elif.
# 10. Crie um validador de IMC com categorias usando elif.
#
# #### Sugestão de entrega:
# > 1) Para cada exercício, inclua pelo menos 2 entradas de teste e o resultado esperado.
# > 2) Explique, em uma frase, qual é a entrada, o processamento e a saída do seu programa.
# > 3) Inclua pelo menos 2 comentários de uma linha no código, explicando a intenção de cada parte.

# %%
# Exercício 1
num = float(input('Digite um número: '))

if num < 0:
    print('⚠️ALERTA: Valor digitado é negativo')
print('FIM')
# Out:
# Digite um número:  5
# FIM

# %%
# Exercício 2
num = float(input('Digite um número: '))

if num % 2 == 0:
    print('Número Par')
print('FIM')
# Out:
# Digite um número:  10
# Número Par

# %%
# Exercício 3
limite = 100
valor = float(input('Digite o valor da compra: '))

if valor > limite:
    print('Parabéns: Você Ganhou frete grátis')
print('Total:', valor)
print('FIM')
# Out:
# Digite o valor da compra:  100.01
# Parabéns: Você Ganhou frete grátis
# Total: 100.01
# FIM

# %%
# Exercício 4
idade = int(input('Digite sua idade: '))

if idade >= 18:
    print('Maior de idade')
else:
    print('Menor de idade')
# Out:
# Digite sua idade:  190
# Maior de idade

# %%
# Exercício 5
nota = float(input('Digite sua nota: '))

if nota >= 5:
    print('Parabéns: Está aprovado!')
else:
    print('Está Reprovado')
# Out:
# Digite sua nota:  5.1
# Parabéns: Está aprovado!

# %%
# Exercício 6
n1 = float(input('Digite um número: '))
n2 = float(input('Digite outro número: '))

if n1 > n2:
    print(n1, 'é maior que', n2)
elif n1 == n2:
    print(n1 ,'e', n2 , 'são iguais')
else:
    print(n2, 'é maior que', n1)
# Out:
# Digite um número:  2.1
# Digite outro número:  2.1
# 2.1 e 2.1 são iguais

# %%
# Exercício 7
print('Escolha o menu, digite:\n 1- Para arroz \n 2- Para Macarrão ')
num = int(input('Digite o valor de acordo com o menu: '))

if num == 1:
    print('Arroz é ótimo')
else:
    print('Macarrão é ótimo')
# Out:
# Escolha o menu, digite:
#  1- Para arroz
#  2- Para Macarrão
# Digite o valor de acordo com o menu:  1
# Arroz é ótimo

# %%
# Exercício 8
hora = float(input('Digite o tempo de permanência em horas: '))

if hora  >= 2:
    print('Tempo:', hora, 'Valor', 20.00)
elif hora >= 1:
    print('Tempo', hora, 'Valor', 10.00)
else:
    print('Tempo', hora, 'Valor', 5.00)
# Out:
# Digite o tempo de permanência em horas:  0.5
# Tempo 0.5 Valor 5.0

# %%
# Exercício 9
temperatura = float(input('Digite o valor da temperatura do paciente:'))

if  temperatura >= 40 or temperatura <= 34:
    print('🔴Prioridade Alta')
elif temperatura >= 38:
    print('🟡Prioridade Média')
else:
    print('🟢Prioridade Baixa')
# Out:
# Digite o valor da temperatura do paciente 36
# 🟢Prioridade Baixa

# %%
# Exercício 10
peso = float(input('Digite o seu peso (em kg):'))
altura = float(input('Digite a sua altura (em m):'))
imc = peso / (altura * altura)

if imc >= 30:
    print('Obesidade')
elif imc >= 25 and imc <= 29.9:
    print('Sobrepeso')
elif imc >= 18.5 and imc <= 24.9:
    print('Peso Normal')
else:
    print('Abaixo do Peso')
# Out:
# Digite o seu peso (em kg): 110
# Digite a sua altura (em m): 1.93
# Sobrepeso

# %% [markdown]
# ## Autoavaliação
#
# Para cada exercício, verifique:
# - seu programa funciona para pelo menos 2 entradas diferentes?
# - você entende por que funciona?
# - você consegue explicar a lógica sem ler o código?
